# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Bruno/POO_IFAL/blob/main/Polimorfismo_e_Interfaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Polimorfismo**

# %% [markdown]
# > Poli = “muitos”; Morfo - “forma”.
#
#
#
# > Em programação orientada a objetos polimorfismo se refere a capacidade de objetos responderem de formas distintas a uma mesma requisição.
#
#
# > Polimorfismo é o princípio pelo qual duas ou mais classes derivadas de uma mesma superclasse podem invocar métodos que têm a mesma identificação (assinatura) mas comportamentos distintos, especializados para cada classe derivada, usando para tanto uma referência a um objeto do tipo da superclasse. A decisão sobre qual o método que deve ser selecionado, de acordo com o tipo da classe derivada, é tomada em tempo de execução, através do mecanismo de ligação tardia.
#
#
#
# > No caso de polimorfismo, é necessário que os métodos tenham exatamente a mesma identificação, sendo utilizado o mecanismo de redefinição de métodos. Esse mecanismo de redefinição não deve ser confundido com o mecanismo de sobrecarga de métodos.

# %% [markdown]
# ![Polimorfismo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1.   Polimorfismo est´a ligado ao conceito de sobreescrita (overriding)
# e sobrecarga (overloading).
#
# 2.   Sobreescrita ocorre quando uma subclasse reimplementa um
# m´etodo existente na superclasse.
#
# 3.   Sobrecarga ocorre quando um m´etodo com mesmo nome possui
# diferentes parˆametros (quantidade e/ou tipos).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Codificação**

# %% [markdown]
# > **Conta Corrente**

# %%
class conta_corrente(object):
  def __init__(self, nome, saldo):
    self.__nome_do_cliente = nome
    self.__saldo_do_cliente = saldo

  def get_saldo(self):
    return  self.__saldo_do_cliente
    
  def deposito(self, valor):
    self.__saldo_do_cliente = self.__saldo_do_cliente + valor

  def sacar(self, valor):
    if self.__saldo_do_cliente < valor:
      return False
    else:
      self.__saldo_do_cliente = self.__saldo_do_cliente - valor
      return True

# %% [markdown]
# > **Conta Especial**

# %%
class conta_especial(conta_corrente):
  def __init__(self, nome, saldo, limite):
    super().__init__(nome, saldo)
    self.__nome = nome
    self.__saldo = saldo
    self.__limite = limite

  def sacar(self, valor):
    if self.__saldo + self.__limite < valor:
      return False
    else:
       self.__saldo = self.__saldo - valor
       return True

# %% [markdown]
# # Referência Bibliográfica

# %% [markdown]
# [Polimorfismo](https://www.dca.fee.unicamp.br/cursos/PooJava/polimorf/index.html)
#
# Material do Professor Alexandre de Andrade Barbosa do curso de Ciência da Computação da Universidade Federal de Alagoas - UFAL / Campus Arapiraca
