# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Bruno/POO_IFAL/blob/main/Heran%C3%A7a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Herança**

# %% [markdown]
# > Herança é um princípio de orientação a objetos, que permite que classes compartilhem atributos e métodos, através de "heranças". Ela é usada na intenção de reaproveitar código ou comportamento generalizado ou especializar operações ou atributos. O conceito de herança de várias classes é conhecido como herança múltipla. Como exemplo pode-se observar as classes 'aluno' e 'professor', onde ambas possuem atributos como nome, endereço e telefone.
#
# > Nesse caso pode-se criar uma nova classe chamada por exemplo, 'pessoa', que contenha as semelhanças entre as duas classes, fazendo com que aluno e professor herdem as características de pessoa, desta maneira pode- se dizer que aluno e professor são subclasses de pessoa. Também podemos dizer que uma classe pode ser abstrata(abstract) ou seja ela não pode ter uma instância, ela apenas "empresta" seus atributos e métodos como molde para novas classes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Herança no Python**

# %%
class Veiculo(object):
    estado = "novo"

class Carro(Veiculo):
    pass


bmw = Carro()
print("Estado do Carro: {}".format(bmw.estado))
# Out:
# Estado do Carro: novo

# %% [markdown]
# # **Codificação**

# %% [markdown]
# > **Conta Corrente**

# %%
class conta_corrente(object):
  def __init__(self, nome, saldo):
    self.__nome_do_cliente = nome
    self.__saldo_do_cliente = saldo

  def get_saldo(self):
    return  self.__saldo_do_cliente
    
  def deposito(self, valor):
    self.__saldo_do_cliente = self.__saldo_do_cliente + valor

  def sacar(self, valor):
    if self.__saldo_do_cliente <= valor:
      return False
    else:
      self.__saldo_do_cliente = self.__saldo_do_cliente - valor
      return True

# %% [markdown]
# > **Conta Especial**

# %%
class conta_especial(conta_corrente):
  def __init__(self, nome, saldo, limite):
    super().__init__(nome, saldo)
    self.__nome = nome
    self.__saldo = saldo
    self.__limite = limite

  def sacar(self, valor):
    if self.__saldo + self.__limite <= valor:
      return False
    else:
       self.__saldo = self.__saldo - valor
       return True

# %% [markdown]
# > **Exemplo**

# %%
bruno = conta_especial("Bruno", 1000, 200)
print("Seu saldo é de {} reais".format(bruno.get_saldo()))
# Out:
# Seu saldo é de 1000 reais

# %% [markdown]
# # Referência Bibliográfica

# %% [markdown]
# [PensePython](https://panda.ime.usp.br/pensepy/static/pensepy/13-Classes/classesintro.html)
#
# [Wikipédia](https://pt.wikipedia.org/wiki/Heran%C3%A7a_(programa%C3%A7%C3%A3o_orientada_a_objetos)
